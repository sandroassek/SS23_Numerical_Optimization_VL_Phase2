# %%
import numpy as np
import pandas as pd
import time

# %%
def simplex_method(A: np.array, c: np.array, b: np.array, x_0: np.array, init_B_index_set: np.array):
    # determine execution time of algorithm
    starting_time = time.time()
    # calcualte calligraphic B and N (Basic- and NonBasic Index Sets)
    basic_index_set = init_B_index_set
    nonbasic_index_set = list([x for x in list([i for i in range(0, A.shape[1]-1)]) if x not in basic_index_set])
    x = x_0
    
    df = pd.DataFrame(columns=['Iteration', 'Basic', 'Non-Basic', 'x_B','x_N', 'x_old', 'lambda', 's_N', 's_N>=0, Optimal sol.?', 'q_indices', 'q', 'd', 'd<=0, Unbounded problem?', 'x_B_plus', 'x_N_plus', 'x_new'])
    df.loc[len(df)] = [0, basic_index_set, nonbasic_index_set, '---', '---', np.round(x_0, 3), '---', '---', False, '---', '---', '---', False, '---', '---', '---']
    
    iterations=1
    break_out_condition = -1
    """
    do simplex method until either:
        - find optimal point (0)
        - detect unboundness (1)
        - Errors (2)
    """
    while True:
        # calcualte B, N
        B = A[:, basic_index_set]
        N = A[:, nonbasic_index_set]

        # calcualte x_B, x_N
        x_B = np.linalg.inv(B) @ b
        x_N = np.zeros(c.shape[0] - b.shape[0])

        # calcualte c_B and c_N
        c_B = c[basic_index_set]
        c_N = c[nonbasic_index_set]

        # get lambda
        lambda_ = np.linalg.solve(B.T, c_B)

        # calculate s_N
        s_N = np.subtract(c_N, (N.T @ lambda_))

        is_optimal_sol = False
        # 1st exit condition: Optimal point found
        if np.all(s_N >= 0): 
            break_out_condition = 0
            df.loc[len(df)] = [iterations, basic_index_set, nonbasic_index_set, np.round(x_B, 3), np.round(x_N, 3), np.round(x, 3), np.round(lambda_, 3), np.round(s_N, 3), True, '---', 
                               '---', '---', False, '---', '---', '---']
            return df, x, f'Algorithm took {(time.time() - starting_time) * 1000} ms to run'

        # select q
        q_indices = []
        for i, s_i in enumerate(s_N):
            if s_i < 0:
                q_indices += [i]
        q_min_idx = q_indices[0]

        # get d
        A_q = A[:, q_min_idx] 
        d = np.linalg.solve(B, A_q)

        # 2nd exit condition: problem is unbounded
        if np.all(d <= 0): 
            break_out_condition = 1
            df.loc[len(df)] = [iterations, basic_index_set, nonbasic_index_set, np.round(x_B, 3), np.round(x_N, 3), np.round(x, 3), np.round(lambda_, 3), np.round(s_N, 3), False, q_indices, 
                               q_min_idx, d, False, np.round(x_B_plus, 3), np.round(x_N_plus, 3), np.round(x_new, 3)]
            return df, _, f'Algorithm took {(time.time() - starting_time) * 1000} ms to run'

        # calcualte x_q^+ and p
        x_q_plus_all = []
        for i, d_i in enumerate(d):
            if d_i > 0:
                x_q_plus_all += [x_B[i]/d_i]
                
        if len(x_q_plus_all) == 0: raise ValueError('Could not find any appropriate q')
        
        p_min_idx = np.argmin(x_q_plus_all)
        x_q_plus = np.min(x_q_plus_all)

        # update x_B^+
        x_B_plus = np.subtract(x_B, (d * x_q_plus))

        # update x_N_^+
        x_N_plus = x_N
        entering_var = -1 # needed for updating N and x_N_plus
        for idx in nonbasic_index_set:
            if idx == q_min_idx:
                entering_var = idx
                break
        # check for validity of varaible that changes N and x_N_plus
        if entering_var == -1: raise ValueError('Entering variable for N is undefined')
        x_N_plus[entering_var] = x_q_plus
        
        # update x according to indices
        x_new = x.copy()
        x_new[basic_index_set] = x_B_plus
        x_new[nonbasic_index_set] = x_N_plus

        # update basic- and nonbasic index set
        basic_index_set_copy = basic_index_set.copy()
        basic_index_set[p_min_idx] = q_min_idx
        nonbasic_index_set[entering_var] = basic_index_set_copy[p_min_idx]       
        
        df.loc[len(df)] = [iterations, basic_index_set, nonbasic_index_set, np.round(x_B, 3), np.round(x_N, 3), np.round(x, 3), np.round(lambda_, 3), np.round(s_N, 3), False, q_indices, 
                            q_min_idx, d, False, np.round(x_B_plus, 3), np.round(x_N_plus, 3), np.round(x_new, 3)]
        x = x_new
        iterations += 1

# %%
# Example 13.1 from book:
A = np.array([[1,1,1,0],[2,1/2,0,1]], dtype=np.float64)
c = np.array([-4, -2], dtype=np.float64)

# extends c to 4d (same dim as A)
missing_dims_c = A.shape[1] - c.shape[0]
c = np.append(c, np.array([0] * missing_dims_c))

b = np.array([5, 8], dtype=np.float64)
x_0 = np.array([0, 0, 5, 8], dtype=np.float64)

# determine calligraphical B
init_B_index_set = np.array([2, 3], dtype=np.int16)

df, optimal_point, execution_time = simplex_method(A=A, c=c, b=b, x_0=x_0, init_B_index_set=init_B_index_set)

# %%
df
# Out:
#    Iteration   Basic Non-Basic             x_B           x_N  \
# 0          0  [1, 0]    [3, 2]             ---           ---
# 1          1  [1, 0]    [3, 2]      [5.0, 8.0]    [4.0, 0.0]
# 2          2  [1, 0]    [3, 2]      [1.0, 4.0]  [0.0, 1.333]
# 3          3  [1, 0]    [3, 2]  [1.333, 3.667]    [0.0, 0.0]
#
#                       x_old            lambda             s_N  \
# 0      [0.0, 0.0, 5.0, 8.0]               ---             ---
# 1      [0.0, 0.0, 5.0, 8.0]        [0.0, 0.0]    [-4.0, -2.0]
# 2      [4.0, 0.0, 1.0, 0.0]       [0.0, -2.0]     [2.0, -1.0]
# 3  [3.667, 1.333, 0.0, 0.0]  [-1.333, -1.333]  [1.333, 1.333]
#
#    s_N>=0, Optimal sol.? q_indices    q             d  \
# 0                  False       ---  ---           ---
# 1                  False    [0, 1]    0    [1.0, 2.0]
# 2                  False       [1]    1  [0.75, 0.25]
# 3                   True       ---  ---           ---
#
#    d<=0, Unbounded problem?      x_B_plus      x_N_plus  \
# 0                     False           ---           ---
# 1                     False    [1.0, 0.0]    [4.0, 0.0]
# 2                     False  [0.0, 3.667]  [0.0, 1.333]
# 3                     False           ---           ---
#
#                       x_new
# 0                       ---
# 1      [4.0, 0.0, 1.0, 0.0]
# 2  [3.667, 1.333, 0.0, 0.0]
# 3                       ---

# %%
execution_time
# Out:
# 'Algorithm took 6.848335266113281 ms to run'

# %%
# Example HW from book:
A = np.array([[1,1,1,0],[2,1/2,0,1]], dtype=np.float64)
c = np.array([-5, -1], dtype=np.float64)

# extends c to 4d (same dim as A)
missing_dims_c = A.shape[1] - c.shape[0]
c = np.append(c, np.array([0] * missing_dims_c))

b = np.array([5, 8], dtype=np.float64)
x_0 = np.array([0, 0, 5, 8], dtype=np.float64)

# determine calligraphical B
init_B_index_set = np.array([2, 3], dtype=np.int16)

df, optimal_point, execution_time = simplex_method(A=A, c=c, b=b, x_0=x_0, init_B_index_set=init_B_index_set)

# %%
df
# Out:
#    Iteration   Basic Non-Basic         x_B         x_N                 x_old  \
# 0          0  [2, 0]    [3, 1]         ---         ---  [0.0, 0.0, 5.0, 8.0]
# 1          1  [2, 0]    [3, 1]  [5.0, 8.0]  [4.0, 0.0]  [0.0, 0.0, 5.0, 8.0]
# 2          2  [2, 0]    [3, 1]  [1.0, 4.0]  [0.0, 0.0]  [4.0, 0.0, 1.0, 0.0]
#
#         lambda           s_N  s_N>=0, Optimal sol.? q_indices    q  \
# 0          ---           ---                  False       ---  ---
# 1   [0.0, 0.0]  [-5.0, -1.0]                  False    [0, 1]    0
# 2  [0.0, -2.5]   [2.5, 0.25]                   True       ---  ---
#
#             d  d<=0, Unbounded problem?    x_B_plus    x_N_plus  \
# 0         ---                     False         ---         ---
# 1  [1.0, 2.0]                     False  [1.0, 0.0]  [4.0, 0.0]
# 2         ---                     False         ---         ---
#
#                   x_new
# 0                   ---
# 1  [4.0, 0.0, 1.0, 0.0]
# 2                   ---

# %%
execution_time
# Out:
# 'Algorithm took 7.001161575317383 ms to run'
